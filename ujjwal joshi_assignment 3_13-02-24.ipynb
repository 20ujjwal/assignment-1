# %% [markdown]
# <a href="https://colab.research.google.com/github/20ujjwal/assignment-1/blob/main/ujjwal%20joshi_assignment%203_13-02-24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df=pd.read_csv('/content/data (1).csv')
df
print(df.loc[0])
print(df.loc[4])
print(df.loc[7])
print(df.loc[8])
# Out:
# Duration     60.0
# Pulse       110.0
# Maxpulse    130.0
# Calories    409.1
# Name: 0, dtype: float64
# Duration     45.0
# Pulse       117.0
# Maxpulse    148.0
# Calories    406.0
# Name: 4, dtype: float64
# Duration     45.0
# Pulse       104.0
# Maxpulse    134.0
# Calories    253.3
# Name: 7, dtype: float64
# Duration     30.0
# Pulse       109.0
# Maxpulse    133.0
# Calories    195.1
# Name: 8, dtype: float64

# %%
df=pd.read_csv('/content/data (1).csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
